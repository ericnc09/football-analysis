# %%
import soccerdata as sd
# Out:
# [08/02/22 17:29:50] INFO     No custom team name replacements found. You can configure these in       ]8;id=15096;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=237038;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_config.py#85\85]8;;\
#                              /Users/eric/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=670537;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=640354;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_config.py#155\155]8;;\
#                              /Users/eric/soccerdata/config/league_dict.json.

# %%
fbref = sd.FBref()
# Out:
# [08/02/22 17:29:53] INFO     Saving cached data to /Users/eric/soccerdata/data/FBref                  ]8;id=394275;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=445862;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py#89\89]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=165861;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=284237;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py#291\291]8;;\
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py:465: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg)

# %%
fbref = sd.FBref(data_dir="/tmp", no_cache=True, no_store=True)
# Out:
# [08/02/22 17:29:57] INFO     Caching is disabled                                                      ]8;id=609643;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=223763;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py#87\87]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=980838;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=411001;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py#291\291]8;;\

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons=2021)
print(fbref.__doc__)
# Out:
# [08/02/22 17:32:29] INFO     Saving cached data to /Users/eric/soccerdata/data/FBref                  ]8;id=14564;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=292793;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/_common.py#89\89]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include.
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
# ...

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="standard")

# %%
team_season_stats.head()
# Out:
#                                       # Pl   Age  Poss Playing Time         \
#                                                                  MP Starts
# league             season team
# ENG-Premier League 2021   Arsenal       29  25.9  53.8           38    418
#                           Aston Villa   24  25.2  48.1           38    418
#                           Brighton      27  25.8  51.3           38    418
#                           Burnley       25  28.3  41.7           38    418
#                           Chelsea       27  26.0  61.4           38    418
#
#                                                   Performance           ...  \
#                                         Min   90s         Gls Ast G-PK  ...
# league             season team                                          ...
# ENG-Premier League 2021   Arsenal      3420  38.0          53  38   47  ...
#                           Aston Villa  3420  38.0          52  38   47  ...
# ...

# %%
player_season_stats = fbref.read_player_season_stats(stat_type="standard")
player_season_stats.head()
# Out:
# https://fbref.com/en/squads/18bb7c10/2020-2021/Arsenal-Stats
# https://fbref.com/en/squads/8602292d/2020-2021/Aston-Villa-Stats
# https://fbref.com/en/squads/d07537b9/2020-2021/Brighton-and-Hove-Albion-Stats
# https://fbref.com/en/squads/943e8050/2020-2021/Burnley-Stats
# https://fbref.com/en/squads/cff3d9bb/2020-2021/Chelsea-Stats
# https://fbref.com/en/squads/47c64c55/2020-2021/Crystal-Palace-Stats
# https://fbref.com/en/squads/d3fd31cc/2020-2021/Everton-Stats
# https://fbref.com/en/squads/fd962109/2020-2021/Fulham-Stats
# https://fbref.com/en/squads/5bfb9659/2020-2021/Leeds-United-Stats
# https://fbref.com/en/squads/a2d435b3/2020-2021/Leicester-City-Stats
# https://fbref.com/en/squads/822bd0ba/2020-2021/Liverpool-Stats
# https://fbref.com/en/squads/b8fd03ef/2020-2021/Manchester-City-Stats
# https://fbref.com/en/squads/19538871/2020-2021/Manchester-United-Stats
# https://fbref.com/en/squads/b2b47a98/2020-2021/Newcastle-United-Stats
# ...

# %%
epl_schedule = fbref.read_schedule()
epl_schedule.head()
# Out:
#                                                                  week  day  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton   1.0  Sat
#                           2020-09-12 Fulham-Arsenal               1.0  Sat
#                           2020-09-12 Liverpool-Leeds United       1.0  Sat
#                           2020-09-12 West Ham-Newcastle Utd       1.0  Sat
#                           2020-09-13 Tottenham-Everton            1.0  Sun
#
#                                                                       date  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton 2020-09-12
#                           2020-09-12 Fulham-Arsenal             2020-09-12
#                           2020-09-12 Liverpool-Leeds United     2020-09-12
#                           2020-09-12 West Ham-Newcastle Utd     2020-09-12
#                           2020-09-13 Tottenham-Everton          2020-09-13
#
# ...

# %%
lineups = fbref.read_lineup(match_id='21b58926')
lineups.head()
# Out:
# [08/02/22 17:33:34] INFO     [3/1] Retrieving game with id=21b58926                                    ]8;id=758599;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py\fbref.py]8;;\:]8;id=913183;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py#415\415]8;;\
#                                                                                           jersey_number  \
# league             season game                              team      player
# ENG-Premier League 2021   2020-09-12 Liverpool-Leeds United Liverpool Alisson                         1
#                                                                       Virgil van Dijk                 4
#                                                                       Georginio Wijnaldum             5
#                                                                       Naby Keïta                      8
# ...

# %%
player_match_stats = fbref.read_player_match_stats(stat_type="passing", match_id='21b58926')
player_match_stats.head()
# Out:
# [08/02/22 17:34:01] INFO     [3/1] Retrieving game with id=21b58926                                    ]8;id=684436;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py\fbref.py]8;;\:]8;id=771508;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py#498\498]8;;\
#                                                                                           Long  \
#                                                                                            Att
# league             season game                              team         player
# ENG-Premier League 2021   2020-09-12 Liverpool-Leeds United Leeds United Hélder Costa        3
#                                                                          Illan Meslier      29
#                                                                          Jack Harrison       2
# ...

# %%
shots = fbref.read_shot_events(match_id='21b58926')
shots.tail()
# Out:
# [08/02/22 17:34:34] INFO     [3/1] Retrieving game with id=21b58926                                    ]8;id=422790;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py\fbref.py]8;;\:]8;id=449566;file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/soccerdata/fbref.py#581\581]8;;\
#                                                                                       minute  \
#
# league             season game                              team      player
# ENG-Premier League 2021   2020-09-12 Liverpool-Leeds United Liverpool Sadio Mané          62
#                                                                       Sadio Mané          68
#                                                                       Sadio Mané          71
#                                                                       Virgil van Dijk     20
# ...
