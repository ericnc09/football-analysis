# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %%
df = pd.read_csv('europa_final.csv')

# %%
df.head(20)
# Out:
#     minute  second             teamId     x     y     period       type  \
# 0        0     0.0  Manchester United   0.0   0.0  FirstHalf      Start
# 1        0     0.0         Villarreal   0.0   0.0  FirstHalf      Start
# 2        0     0.0  Manchester United  49.9  50.0  FirstHalf       Pass
# 3        0     3.0  Manchester United  32.2  58.1  FirstHalf       Pass
# 4        0    32.0         Villarreal  34.4   0.0  FirstHalf       Pass
# 5        0    34.0         Villarreal  35.1   9.1  FirstHalf       Pass
# 6        0    35.0         Villarreal  33.6   2.6  FirstHalf     TakeOn
# 7        0    35.0  Manchester United  66.4  97.4  FirstHalf     Tackle
# 8        0    52.0         Villarreal  34.2   0.0  FirstHalf       Pass
# 9        0    54.0         Villarreal  34.1  14.0  FirstHalf       Pass
# 10       0    55.0         Villarreal  30.0  53.3  FirstHalf       Foul
# 11       0    55.0  Manchester United  70.0  46.7  FirstHalf       Foul
# 12       1     5.0         Villarreal  26.1  65.7  FirstHalf       Pass
# 13       1    10.0         Villarreal  33.3  87.1  FirstHalf       Pass
# 14       1    14.0         Villarreal  26.6  76.6  FirstHalf       Pass
# 15       1    19.0         Villarreal  28.6   5.9  FirstHalf       Pass
# 16       1    23.0         Villarreal  30.3  12.6  FirstHalf       Pass
# 17       1    28.0         Villarreal  19.6  15.0  FirstHalf       Pass
# 18       1    35.0  Manchester United  62.7  16.6  FirstHalf  Challenge
# 19       1    35.0         Villarreal  37.3  83.4  FirstHalf     TakeOn
#
#          outcome  playerId  endX   endY
# 0     Successful       NaN   NaN    NaN
# 1     Successful       NaN   NaN    NaN
# 2     Successful      18.0  31.5   59.6
# 3   Unsuccessful       2.0  69.6  100.0
# 4     Successful       8.0  36.5    9.5
# 5     Successful       7.0  31.9    2.3
# 6   Unsuccessful       8.0   NaN    NaN
# 7     Successful      10.0   NaN    NaN
# 8     Successful       8.0  35.0   10.6
# 9     Successful       5.0  31.3   37.4
# 10    Successful      14.0   NaN    NaN
# 11  Unsuccessful      11.0   NaN    NaN
# 12    Successful       4.0  34.0   87.1
# 13    Successful      24.0  21.9   75.7
# 14    Successful       4.0  24.1    5.9
# 15    Successful       8.0  43.0    4.1
# 16    Successful      30.0  14.4   13.1
# 17    Successful       3.0  25.0   92.4
# 18  Unsuccessful      29.0   NaN    NaN
# 19    Successful      24.0   NaN    NaN

# %%
df = df.loc[df['teamId']=='Manchester United']

# %%
df = df.loc[df['type']=='Pass']

# %%
df = df.loc[df['playerId']>=0.0].reset_index()

# %%
df = df.loc[df['outcome']=='Successful'].reset_index()

# %%
df.x = df.x*1.2
df.y = df.y*.8
df.endX = df.endX*1.2
df.endY = df.endY*1.2

# %%
df['beginning'] = np.sqrt(np.square(120-df['x']) + np.square(40 - df['y']))
df['end'] = np.sqrt(np.square(120 - df['endX']) + np.square(40 - df['endY']))

df['outcome'] = [(df['end'][x]) / (df['beginning'][x]) < .65 for x in range(len(df.beginning))]

# %%
pitch = Pitch(pitch_type='statsbomb')
fig,ax = pitch.draw()

pitch.lines(df.x,df.y,df.endX,df.endY,comet=True,ax=ax)
