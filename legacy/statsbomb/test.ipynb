# %%
print ("Hello")
# Out:
# Hello

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

import mplsoccer
import matplotlib.pyplot as plt

# %%
base_url = 'https://understat.com/match/17260'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id:

# %%
url
# Out:
# 'https://understat.com/match/17260'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22441994\x22,\x22minute\x22\x3A\x225\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.7030000305175781\x22,\x22Y\x22\x3A\x220.5379999923706055\x22,\x22xG\x22\x3A\x220.012678555212914944\x22,\x22player\x22\x3A\x22Lee\x20Kang\x2DIn\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227313\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2217260\x22,\x22h_team\x22\x3A\x22Mallorca\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Salva\x20Sevilla\x22,\x22lastAction\x22\x3A\x22TakeOn\x22\x7D,\x7B\x22id\x22\x3A\x22441995\x22,\x22minute\x22\x3A\x225\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.8859999847412109\x22,\x22Y\x22\x3A\x220.534000015258789\x22,\x22xG\x22\x3A\x220.3145849406719208\x22,\x22player\x22\x3A\x22\x5Cu00c1ngel\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x224136\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2217260\x22,\x22h_team\x22\x3A\x22Mallorca\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Dani\x20Rodr\x5Cu00edguez\x22,\x22lastAction\x22\x3A\x22Chipped\x22\x7D,\x7B\x22id\x22\x3A\x22441996\x22,\x22minute\x22\x3A\x227\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.765\x22,\x22Y\x22\x3A\x220.605999984741211\x22,\x22xG\x22\x3A\x220.020615534856915474\x22,\x22player\x22\x3A\x22Jaume\x20Costa\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222539\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2217260\x22,\x22h_team\x22\x3A\x22Mallorca\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22None\x22\x7D,\x7B\x22id\x22\x3A\x22441999\x22,\x22minute\x22\x3A\x2215\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.7380000305175781\x22,\x22Y\x22\x3A\x220.3270000076293945\x22,\x22xG\x22\x3A\x220.011316795833408833\x22,\x22player\x22\x3A\x22Iddrisu\x20Baba\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227840\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2217260\x22,\x22h_team\x22\x3A\x22Mallorca\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22None\x22\x7D,\x7B\x22id\x22\x3A\x22442000\x22,\x22minute\x22\x3A\x2225\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.85\x22,\x22Y\x22\x3A\x220.3890000152587891\x22,\x22xG\x22\x3A\x220.0678015723824501\x22,\x22player\x22\x3A\x22\x5Cu00c1ngel\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x224136\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2217260\x22,\x22h_team\x22\x3A\x22Mallorca\x22,\x22a_team\x22\x3A\x22Elche\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22BallRecovery\x22\x7D,\x7B\x22id\x22\x3A\x22442004\x22,\x22minute\x22\x3A\x2239\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.78\x22,\x22Y\x22\x3A\x220.6809999847412109\x22,\x22xG\x22\x3A\x220.06917748600244522\x22,\x22player\x22\x3A\x22Salva\x20Sevilla\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222121\x22,\x22situation\x22\x3 ...
#  		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2217260\x22,\x22fid\x22\x3A\x221559910\x22,\x22h\x22\x3A\x22239\x22,\x22a\x22\x3A\x22207\x22,\x22date\x22\x3A\x222021\x2D11\x2D07\x2017\x3A30\x3A00\x22,\x22league_id\x22\x3A\x224\x22,\x22season\x22\x3A\x222021\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Mallorca\x22,\x22team_a\x22\x3A\x22Elche\x22,\x22h_xg\x22\x3A\x222.04894\x22,\x22a_xg\x22\x3A\x220.679919\x22,\x22h_w\x22\x3A\x220.7471\x22,\x22h_d\x22\x3A\x220.1813\x22,\x22h_l\x22\x3A\x220.0716\x22,\x22league\x22\x3A\x22La\x20liga\x22,\x22h_shot\x22\x3A\x2218\x22,\x22a_shot\x22\x3A\x227\x22,\x22h_shotOnTarget\x22\x3A\x226\x22,\x22a_shotOnTarget\x22\x3A\x222\x22,\x22h_deep\x22\x3A\x227\x22,\x22a_deep\x22\x3A\x222\x22,\x22a_ppda\x22\x3A\x229.3182\x22,\x22h_ppda\x22\x3A\x226.7097\x22\x7D');
#  </script>,
#  <script>
#  	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22495060\x22\x3A\x7B\x22id\x22\x3A\x22495060\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227836\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22Manolo\x20Reina\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22495061\x22\x3A\x7B\x22id\x22\x3A\x22495061\x22,\x22goals\x22\x3A\x221\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.15358179807662964\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x221003\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Pablo\x20Maffeo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.08560149371623993\x22,\x22xGBuildup\x22\x3A\x220.08560149371623993\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22495062\x22\x3A\x7B\x22id\x22\x3A\x22495062\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.09191708266735077\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227838\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Martin\x20Valjent\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.09191708266735077\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22495063\x22\x3A\x7B\x22id\x22\x3A\x22495063\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x229757\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Franco\x20Russo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x221\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.030725162476301193\x22,\x22xGBuildup\x22\x3A\x220.030725162476301193\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22495064\x22\x3A\x7B\x22id\x22\x3A\x22495064\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.020615534856915474\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x222539\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Jaume\x20Costa\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x221\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220.018046608194708824\x22,\x22xGChain\x22\x3A\x220.07033484429121017\x22,\x22xGBuildup\x22\x3A\x220.03167269751429558\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22495065\x22\x3A\x7B\x22id\x22\x3A\x22495065\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.031169723719358444\x22,\x22time\x22\x3A\x2277\x22,\x22player_id\x22\x3A\x227840\x22,\x22team_id\x22\x3A\x22239\x22,\x22position\x22\x3A\x22DMC\x22,\x22player\x22\x3A\x22Iddrisu\x20Baba\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x221\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_ ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x223729\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22441994\\x22,\\x22minute\\x22\\x3A\\x225\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.7030000305175781\\x22,\\x22Y\\x22\\x3A\\x220.5379999923706055\\x22,\\x22xG\\x22\\x3A\\x220.012678555212914944\\x22,\\x22player\\x22\\x3A\\x22Lee\\x20Kang\\x2DIn\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227313\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2217260\\x22,\\x22h_team\\x22\\x3A\\x22Mallorca\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D11\\x2D07\\x2017\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Salva\\x20Sevilla\\x22,\\x22lastAction\\x22\\x3A\\x22TakeOn\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22441995\\x22,\\x22minute\\x22\\x3A\\x225\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.8859999847412109\\x22,\\x22Y\\x22\\x3A\\x220.534000015258789\\x22,\\x22xG\\x22\\x3A\\x220.3145849406719208\\x22,\\x22player\\x22\\x3A\\x22\\x5Cu00c1ngel\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x224136\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2217260\\x22,\\x22h_team\\x22\\x3A\\x22Mallorca\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D11\\x2D07\\x2017\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Dani\\x20Rodr\\x5Cu00edguez\\x22,\\x22lastAction\\x22\\x3A\\x22Chipped\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22441996\\x22,\\x22minute\\x22\\x3A\\x227\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.765\\x22,\\x22Y\\x22\\x3A\\x220.605999984741211\\x22,\\x22xG\\x22\\x3A\\x220.020615534856915474\\x22,\\x22player\\x22\\x3A\\x22Jaume\\x20Costa\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222539\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2217260\\x22,\\x22h_team\\x22\\x3A\\x22Mallorca\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D11\\x2D07\\x2017\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3Anull,\\x22lastAction\\x22\\x3A\\x22None\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22441999\\x22,\\x22minute\\x22\\x3A\\x2215\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.7380000305175781\\x22,\\x22Y\\x22\\x3A\\x220.3270000076293945\\x22,\\x22xG\\x22\\x3A\\x220.011316795833408833\\x22,\\x22player\\x22\\x3A\\x22Iddrisu\\x20Baba\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227840\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2217260\\x22,\\x22h_team\\x22\\x3A\\x22Mallorca\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D11\\x2D07\\x2017\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3Anull,\\x22lastAction\\x22\\x3A\\x22None\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22442000\\x22,\\x22minute\\x22\\x3A\\x2225\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.85\\x22,\\x22Y\\x22\\x3A\\x220.3890000152587891\\x22,\\x22xG\\x22\\x3A\\x220.0678015723824501\\x22,\\x22player\\x22\\x3A\\x22\\x5Cu00c1ngel\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x224136\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2217260\\x22,\\x22h_team\\x22\\x3A\\x22Mallorca\\x22,\\x22a_team\\x22\\x3A\\x22Elche\\x22,\\x22h_g ...

# %%
# strip unnecessary symbols and get only JSON data 
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '441994',
#    'minute': '5',
#    'result': 'BlockedShot',
#    'X': '0.7030000305175781',
#    'Y': '0.5379999923706055',
#    'xG': '0.012678555212914944',
#    'player': 'Lee Kang-In',
#    'h_a': 'h',
#    'player_id': '7313',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Salva Sevilla',
#    'lastAction': 'TakeOn'},
#   {'id': '441995',
#    'minute': '5',
#    'result': 'SavedShot',
#    'X': '0.8859999847412109',
#    'Y': '0.534000015258789',
#    'xG': '0.3145849406719208',
#    'player': 'Ángel',
#    'h_a': 'h',
#    'player_id': '4136',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Dani Rodríguez',
#    'lastAction': 'Chipped'},
#   {'id': '441996',
#    'minute': '7',
#    'result': 'BlockedShot',
#    'X': '0.765',
#    'Y': '0.605999984741211',
#    'xG': '0.020615534856915474',
#    'player': 'Jaume Costa',
#    'h_a': 'h',
#    'player_id': '2539',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '441999',
#    'minute': '15',
#    'result': 'MissedShots',
#    'X': '0.7380000305175781',
#    'Y': '0.3270000076293945',
#    'xG': '0.011316795833408833',
#    'player': 'Iddrisu Baba',
#    'h_a': 'h',
#    'player_id': '7840',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '442000',
#    'minute': '25',
#    'result': 'BlockedShot',
#    'X': '0.85',
#    'Y': '0.3890000152587891',
#    'xG': '0.0678015723824501',
#    'player': 'Ángel',
#    'h_a': 'h',
#    'player_id': '4136',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'BallRecovery'},
#   {'id': '442004',
#    'minute': '39',
#    'result': 'BlockedShot',
#    'X': '0.78',
#    'Y': '0.6809999847412109',
#    'xG': '0.06917748600244522',
#    'player': 'Salva Sevilla',
#    'h_a': 'h',
#    'player_id': '2121',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '442005',
#    'minute': '41',
#    'result': 'MissedShots',
#    'X': '0.7319999694824219',
#    'Y': '0.5879999923706055',
#    'xG': '0.01670668087899685',
#    'player': 'Lee Kang-In',
#    'h_a': 'h',
#    'player_id': '7313',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Antonio Sánchez',
#    'lastAction': 'Dispossessed'},
#   {'id': '442006',
#    'minute': '46',
#    'result': 'BlockedShot',
#    'X': '0.759000015258789',
#    'Y': '0.7390000152587891',
#    'xG': '0.018046608194708824',
#    'player': 'Dani Rodríguez',
#    'h_a': 'h',
#    'player_id': '7841',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Jaume Costa',
#    'lastAction': 'Pass'},
#   {'id': '442007',
#    'minute': '52',
#    'result': 'SavedShot',
#    'X': '0.7369999694824219',
#    'Y': '0.5520000076293945',
#    'xG': '0.06198437139391899',
#    'player': 'Lee Kang-In',
#    'h_a': 'h',
#    'player_id': '7313',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '442008',
#    'minute': '62',
#    'result': 'SavedShot',
#    'X': '0.7369999694824219',
#    'Y': '0.4470000076293945',
#    'xG': '0.019852926954627037',
#    'player': 'Iddrisu Baba',
#    'h_a': 'h',
#    'player_id': '7840',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Lee Kang-In',
#    'lastAction': 'Pass'},
#   {'id': '442009',
#    'minute': '62',
#    'result': 'MissedShots',
#    'X': '0.905',
#    'Y': '0.5209999847412109',
#    'xG': '0.3731382489204407',
#    'player': 'Ángel',
#    'h_a': 'h',
#    'player_id': '4136',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Dani Rodríguez',
#    'lastAction': 'HeadPass'},
#   {'id': '442011',
#    'minute': '71',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.7432776093482971',
#    'player': 'Salva Sevilla',
#    'h_a': 'h',
#    'player_id': '2121',
#    'situation': 'Penalty',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '442013',
#    'minute': '80',
#    'result': 'BlockedShot',
#    'X': '0.735',
#    'Y': '0.3579999923706055',
#    'xG': '0.01899414323270321',
#    'player': 'Martin Valjent',
#    'h_a': 'h',
#    'player_id': '7838',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Salva Sevilla',
#    'lastAction': 'Pass'},
#   {'id': '442014',
#    'minute': '80',
#    'result': 'BlockedShot',
#    'X': '0.7980000305175782',
#    'Y': '0.315',
#    'xG': '0.02325110137462616',
#    'player': 'Pablo Maffeo',
#    'h_a': 'h',
#    'player_id': '1003',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'BallTouch'},
#   {'id': '442015',
#    'minute': '88',
#    'result': 'BlockedShot',
#    'X': '0.85',
#    'Y': '0.485',
#    'xG': '0.07292293757200241',
#    'player': 'Martin Valjent',
#    'h_a': 'h',
#    'player_id': '7838',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Inigo Ruiz de Galarreta',
#    'lastAction': 'Pass'},
#   {'id': '442016',
#    'minute': '90',
#    'result': 'SavedShot',
#    'X': '0.779000015258789',
#    'Y': '0.29700000762939455',
#    'xG': '0.06283517926931381',
#    'player': 'Abdón Prats',
#    'h_a': 'h',
#    'player_id': '8014',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '442017',
#    'minute': '93',
#    'result': 'BlockedShot',
#    'X': '0.774000015258789',
#    'Y': '0.6509999847412109',
#    'xG': '0.011427522636950016',
#    'player': 'Dani Rodríguez',
#    'h_a': 'h',
#    'player_id': '7841',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '442018',
#    'minute': '94',
#    'result': 'Goal',
#    'X': '0.9490000152587891',
#    'Y': '0.4620000076293945',
#    'xG': '0.13033069670200348',
#    'player': 'Pablo Maffeo',
#    'h_a': 'h',
#    'player_id': '1003',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Dani Rodríguez',
#    'lastAction': 'Cross'}],
#  'a': [{'id': '441997',
#    'minute': '9',
#    'result': 'BlockedShot',
#    'X': '0.7819999694824219',
#    'Y': '0.5420000076293945',
#    'xG': '0.03232412040233612',
#    'player': 'Omar Mascarell',
#    'h_a': 'a',
#    'player_id': '2456',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Lucas Boyé',
#    'lastAction': 'Pass'},
#   {'id': '441998',
#    'minute': '12',
#    'result': 'MissedShots',
#    'X': '0.8719999694824219',
#    'Y': '0.325',
#    'xG': '0.042682766914367676',
#    'player': 'Lucas Boyé',
#    'h_a': 'a',
#    'player_id': '1189',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Javier Pastore',
#    'lastAction': 'Pass'},
#   {'id': '442001',
#    'minute': '25',
#    'result': 'MissedShots',
#    'X': '0.754000015258789',
#    'Y': '0.590999984741211',
#    'xG': '0.022695420309901237',
#    'player': 'Lucas Pérez',
#    'h_a': 'a',
#    'player_id': '1700',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Javier Pastore',
#    'lastAction': 'Chipped'},
#   {'id': '442002',
#    'minute': '34',
#    'result': 'BlockedShot',
#    'X': '0.8340000152587891',
#    'Y': '0.37099998474121093',
#    'xG': '0.053935859352350235',
#    'player': 'Javier Pastore',
#    'h_a': 'a',
#    'player_id': '3295',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Lucas Boyé',
#    'lastAction': 'Pass'},
#   {'id': '442003',
#    'minute': '35',
#    'result': 'BlockedShot',
#    'X': '0.8859999847412109',
#    'Y': '0.6179999923706054',
#    'xG': '0.09101895987987518',
#    'player': 'Lucas Pérez',
#    'h_a': 'a',
#    'player_id': '1700',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Lucas Boyé',
#    'lastAction': 'Pass'},
#   {'id': '442010',
#    'minute': '67',
#    'result': 'Goal',
#    'X': '0.8980000305175782',
#    'Y': '0.34799999237060547',
#    'xG': '0.07288999110460281',
#    'player': 'Lucas Boyé',
#    'h_a': 'a',
#    'player_id': '1189',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': None,
#    'lastAction': 'BallRecovery'},
#   {'id': '442012',
#    'minute': '74',
#    'result': 'Goal',
#    'X': '0.9119999694824219',
#    'Y': '0.5259999847412109',
#    'xG': '0.3643723726272583',
#    'player': 'Lucas Boyé',
#    'h_a': 'a',
#    'player_id': '1189',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '17260',
#    'h_team': 'Mallorca',
#    'a_team': 'Elche',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-11-07 17:30:00',
#    'player_assisted': 'Johan Mojica',
#    'lastAction': 'Cross'}]}

# %%
x = []
y = []
xG = []
result = []
team = []
data_away = data['a']
data_home = data['h']
player = []

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_home[index][key])

# %%
col_names = ['x','y','xG','result','team','player']
df = pd.DataFrame([x,y,xG,result,team,player],index=col_names)
df = df.T

# %%
df
# Out:
#                      x                    y                    xG  \
# 0   0.7030000305175781   0.5379999923706055  0.012678555212914944
# 1   0.8859999847412109    0.534000015258789    0.3145849406719208
# 2                0.765    0.605999984741211  0.020615534856915474
# 3   0.7380000305175781   0.3270000076293945  0.011316795833408833
# 4                 0.85   0.3890000152587891    0.0678015723824501
# 5                 0.78   0.6809999847412109   0.06917748600244522
# 6   0.7319999694824219   0.5879999923706055   0.01670668087899685
# 7    0.759000015258789   0.7390000152587891  0.018046608194708824
# 8   0.7369999694824219   0.5520000076293945   0.06198437139391899
# 9   0.7369999694824219   0.4470000076293945  0.019852926954627037
# 10               0.905   0.5209999847412109    0.3731382489204407
# 11               0.885                  0.5    0.7432776093482971
# 12               0.735   0.3579999923706055   0.01899414323270321
# 13  0.7980000305175782                0.315   0.02325110137462616
# 14                0.85                0.485   0.07292293757200241
# 15   0.779000015258789  0.29700000762939455   0.06283517926931381
# 16   0.774000015258789   0.6509999847412109  0.011427522636950016
# 17  0.9490000152587891   0.4620000076293945   0.13033069670200348
# 18  0.7819999694824219   0.5420000076293945   0.03232412040233612
# 19  0.8719999694824219                0.325  0.042682766914367676
# 20   0.754000015258789    0.590999984741211  0.022695420309901237
# 21  0.8340000152587891  0.37099998474121093  0.053935859352350235
# 22  0.8859999847412109   0.6179999923706054   0.09101895987987518
# 23  0.8980000305175782  0.34799999237060547   0.07288999110460281
# 24  0.9119999694824219   0.5259999847412109    0.3643723726272583
#
#          result      team          player
# 0   BlockedShot  Mallorca     Lee Kang-In
# 1     SavedShot  Mallorca           Ángel
# 2   BlockedShot  Mallorca     Jaume Costa
# 3   MissedShots  Mallorca    Iddrisu Baba
# 4   BlockedShot  Mallorca           Ángel
# 5   BlockedShot  Mallorca   Salva Sevilla
# 6   MissedShots  Mallorca     Lee Kang-In
# 7   BlockedShot  Mallorca  Dani Rodríguez
# 8     SavedShot  Mallorca     Lee Kang-In
# 9     SavedShot  Mallorca    Iddrisu Baba
# 10  MissedShots  Mallorca           Ángel
# 11         Goal  Mallorca   Salva Sevilla
# 12  BlockedShot  Mallorca  Martin Valjent
# 13  BlockedShot  Mallorca    Pablo Maffeo
# 14  BlockedShot  Mallorca  Martin Valjent
# 15    SavedShot  Mallorca     Abdón Prats
# 16  BlockedShot  Mallorca  Dani Rodríguez
# 17         Goal  Mallorca    Pablo Maffeo
# 18  BlockedShot     Elche     Lee Kang-In
# 19  MissedShots     Elche           Ángel
# 20  MissedShots     Elche     Jaume Costa
# 21  BlockedShot     Elche    Iddrisu Baba
# 22  BlockedShot     Elche           Ángel
# 23         Goal     Elche   Salva Sevilla
# 24         Goal     Elche     Lee Kang-In
